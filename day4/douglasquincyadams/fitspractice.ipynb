# %%
import astropy
import astropy.io
import astropy.io.fits
import numpy
import pprint

# %%
fitsdata = astropy.io.fits.open("../../data/HSC_grizy_example.fits")

# %%
fitsdatatable = fitsdata[1].data

# %%
fitstableasarray = numpy.array(fitsdatatable)

# %%
pprint.pprint( fitsdata[1].header )
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / 8-bit bytes
# NAXIS   =                    2 / 2-dimensional table
# NAXIS1  =                  440 / width of table in bytes
# NAXIS2  =                 4972 / number of rows in table
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group
# TFIELDS =                   46 / number of columns
# COMMENT
# COMMENT  *** End of mandatory fields ***
# COMMENT
# COMMENT
# COMMENT  *** Column names ***
# COMMENT
# TTYPE1  = 'ID      '           / label for column 1
# COMMENT
# COMMENT  *** Column formats ***
# COMMENT
# TFORM1  = 'K       '           / format for column 1
# TTYPE2  = 'RA      '           / label for column 2
# TFORM2  = 'D       '           / format for column 2
# TTYPE3  = 'DC      '           / label for column 3
# TFORM3  = 'D       '           / format for column 3
# TTYPE4  = 'PARENT  '           / label for column 4
# ...

# %%
pprint.pprint( fitsdatatable[0] )
# Out:
# (21474836571, 150.98149389434852, 2.1033656480826175, 0, 7, array([ 8.12850609,  9.94640339, -0.39611897]), 7.5781073570251465, 340.06690912068387, 2.2540943131211919, 119.08726396371539, 3.5960718153778153, 291.15707624832152, 0.67977087156693194, array([ 16.77798221,  23.6231474 ,  -1.0873182 ]), 7.5781073570251465, 876.98830109411222, 5.8405152847136668, 303.77631595775711, 4.3417338499944007, 725.47991227493537, 2.9022900948982224, array([ 7.72893802,  9.32742538, -0.372132  ]), 7.5781073570251465, 713.24841363966152, 14.298574063778247, 147.35220500727792, 5.8074752998543957, 594.7482912031428, 1.5248122673887832, array([ 15.93846112,  22.0326626 ,  -0.09779154]), 7.5781073570251465, 1131.0214446175823, 13.128663048182183, 360.80260778655548, 7.421626826097989, 949.53048085877481, 6.0290846879047697, array([ 19.03104561,  24.96453865,  -0.8916943 ]), 7.5781073570251465, 1216.5340692524455, 10.42305104460422, 487.91423480484605, 9.3347695344669699, 1015.1100695125671, 5.738948000
# ...

# %%
fitsdatatable['R_FLUX_KRON'][0]
# Out:
# 876.98830109411222

# %%
print len(fitsdatatable)
# Out:
# 4972

# %%
def FluxToMagnitude(
    Flux = None,
    MagZero = None,
    ):
    Magnitude = -2.5*numpy.log10(Flux) + MagZero
    return Magnitude

# %%
FluxToMagnitude(Flux = 100.0, MagZero= 100.0)
# Out:
# 95.0

# %%
def rowhasnonans(row = None):
    result = True
    for element in row:
        if numpy.isnan(element):
            result = False
    
    return result

# %%
examplerow1 = numpy.array([0,1,2,3,4,5,6])
print rowhasnonans(examplerow1)
# Out:
# True

# %%
examplerow2 = numpy.array([0,1,2,3,4,5,6, numpy.nan])
print rowhasnonans(examplerow2)
# Out:
# False

# %%
numtry = 0 
for element in fitsdatatable:
    print len(element)
    numtry += 1
# Out:
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# 46
# ...

# %%
def getMagnitudes(
        table = None,
        magzero = None,
        filtercolumnnametofluxcolumnname = None,
    ):
    
    tablemask = numpy.where( rowhasnonans )
    print 'tablemask', tablemask
    
    tablesubset = table[tablemask]
    print tablesubset.shape
    
    reuslt = {}
    for NewColumnName, ColumnName in filtercolumnnametofluxcolumnname.items():
        result[NewColumnName] = FluxToMagnitude( tablesubset[ColumnName] )

# %%
table = fitsdatatable
magzero = 27.0
mags = getMagnitudes(table, magzero, {"r": "R_FLUX_KRON", "i": "I_FLUX_KRON"})
# Out:
# tablemask (array([0]),)
# (1,)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-c0b309399201> in <module>()
#       1 table = fitsdatatable
#       2 magzero = 27.0
# ----> 3 mags = getMagnitudes(table, magzero, {"r": "R_FLUX_KRON", "i": "I_FLUX_KRON"})
#
# <ipython-input-49-0c560992c618> in getMagnitudes(table, magzero, filtercolumnnametofluxcolumnname)
#      13     reuslt = {}
#      14     for NewColumnName, ColumnName in filtercolumnnametofluxcolumnname.items():
# ---> 15         result[NewColumnName] = FluxToMagnitude( tablesubset[ColumnName] )
#
# <ipython-input-21-1a2d476d3c41> in FluxToMagnitude(Flux, MagZero)
#       3     MagZero = None,
#       4     ):
# ----> 5     Magnitude = -2.5*numpy.log10(Flux) + MagZero
#       6     return Magnitude
#
# TypeError: unsupported operand type(s) for +: 'float' and 'NoneType'
